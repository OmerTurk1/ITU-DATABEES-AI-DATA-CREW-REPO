# %% [markdown]
# # ITU DATABEES - AI & DATA CREW HOMEWORK 3
# ### Complete all the tasks and send it back before the deadline. Write clear codes and gain as much point as you can. If needed, please fill the "Answer" parts in questions, otherwise keep it blank. For your educational benefit, AI usage is NOT recommended, try to complete the tasks without using any AI tools. Correct and effective codes will be sent after the deadline.
#
# ### Good Luck.
#
# ### Ömer Türk

# %%
##########################
#### Name:
#### Surname:
##########################

# %% [markdown]
# ## Mission of this homework
# In this notebook, we are going to work on a student performance data, same as HW2. Our objective is to understand the data, perform some operations and gain insights from the dataset, improving our data plotting skills.

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Load Dataset

# %%
df = pd.read_csv("StudentPerformanceFactors.csv")
df.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %% [markdown]
# ## Task 1: Visualize the distribution of the Exam_Score column using a Histogram with a KDE (Kernel Density Estimate) line. What does this distribution tell you about the overall performance of the students?
# Hint: use seaborn

# %%
# FILL HERE

# %% [markdown]
# Answer:

# %% [markdown]
# ## Task 2: Create a Scatter Plot to examine the relationship between Hours_Studied and Exam_Score. What is the dominant trend?

# %%
# FILL HERE

# %% [markdown]
# Answer:

# %% [markdown]
# ## Task 3: Use a Box Plot to compare Exam_Score across different levels of Internet_Access while setting the graph figure size as (10,6). Which group is relatively more successful?

# %%
# FILL HERE

# %% [markdown]
# Answer:

# %% [markdown]
# ## Task 4: Create a Pivot Table that shows the average Exam_Score grouped by School_Type (rows) and Gender (columns).
# Only show the table, this does not require any graph plot

# %%
# FILL HERE

# %% [markdown]
# ## Task 5: Calculate the correlation matrix for all numerical variables and visualize it using a Heatmap. Which variable has the strongest correlation with Exam_Score?
# Note: this will likely take more than one cell, so solve the question using as many cells as you want.

# %%
# FILL HERE

# %% [markdown]
# Answer:

# %% [markdown]
# ## Task 6: Visualize the relationship between Attendance and Exam_Score, but this time use the hue parameter to differentiate between students who have Access_to_Resources (High vs. Low/Medium).

# %%
# FILL HERE

# %% [markdown]
# ## Task 7: Plot the Parental_Involvement and Parental_Education_Level together using column graph. Set the graph title as Parental Involvement by Education Level, and make sure x axis represents to Parental_Education_Level and y axis represents the count.
# hint: use seaborn.countplot

# %%
# FILL HERE
