# %% [markdown]
# # ITU DATABEES - AI & DATA CREW HOMEWORK 1
# ### Complete all the tasks and send it back before the deadline. Write clear codes and gain as much point as you can. For your educational benefit, AI usage is NOT recommended, try to complete the tasks without using any AI tools. You can compare your functions' answers with true answers.

# %% [markdown]
# #### Function Checker Program

# %%
# DO NOT CHANGE HERE
def check_function(samples,sample_answers,checked_function):
    grade = 0
    for sample, right_answer in zip(samples, sample_answers):
        answer = checked_function(sample)
        print(f"{str(sample):<25} -> Right Answer: {str(right_answer):<10} , User Answer: {answer}")
        if answer == right_answer:
            grade += 1
    print("-" * 50)
    print(f"Point: %{round(grade/len(samples)*100 , 3)}")

# %% [markdown]
# # Task 1: Sum of Even Numbers
# Write a function that returns the sum of all even numbers' squares on a list.

# %%
def sum_even_numbers_square(myList):
    # FILL HERE
    return sum([x**2 for x in myList if x%2==0])

# %% [markdown]
# ## Test your function with test cases below:

# %%
# DO NOT CHANGE HERE
check_function(
    [[10,20,30,40,50],[3,4,5,6,7],[-2,6,1,0,25,345],[1,1,1,1,1],[],[-4,3.5,0,56,45,873]],
    [5500, 52, 40, 0, 0, 3152],
    sum_even_numbers_square
)
# Out:
# [10, 20, 30, 40, 50]      -> Right Answer: 5500       , User Answer: 5500
# [3, 4, 5, 6, 7]           -> Right Answer: 52         , User Answer: 52
# [-2, 6, 1, 0, 25, 345]    -> Right Answer: 40         , User Answer: 40
# [1, 1, 1, 1, 1]           -> Right Answer: 0          , User Answer: 0
# []                        -> Right Answer: 0          , User Answer: 0
# [-4, 3.5, 0, 56, 45, 873] -> Right Answer: 3152       , User Answer: 3152
# --------------------------------------------------
# Point: %100.0

# %% [markdown]
# # Task 2: Recursive Factorial
# Complete a recursive factorial function which works in a recursive way.
#
# Constraints:
# - Function needs to work for only integers. If the input is not an integer, it should return an "Error!" message.
# - It is NOT allowed to use any loops in the function.

# %%
def recursive_factorial(n):
    # FILL HERE
    if not isinstance(n,int) or n<0:
        return "Error!"
    if n<=1:
        return 1
    return n * recursive_factorial(n-1)

# %% [markdown]
# ## Test your function with test cases below:

# %%
# DO NOT CHANGE HERE
check_function(
    [0, 2, 5, 12, -1, None, "Hello", 3.5],
    [1, 2, 120, 479001600, "Error!", "Error!", "Error!","Error!"],
    recursive_factorial
)
# Out:
# 0                         -> Right Answer: 1          , User Answer: 1
# 2                         -> Right Answer: 2          , User Answer: 2
# 5                         -> Right Answer: 120        , User Answer: 120
# 12                        -> Right Answer: 479001600  , User Answer: 479001600
# -1                        -> Right Answer: Error!     , User Answer: Error!
# None                      -> Right Answer: Error!     , User Answer: Error!
# Hello                     -> Right Answer: Error!     , User Answer: Error!
# 3.5                       -> Right Answer: Error!     , User Answer: Error!
# --------------------------------------------------
# Point: %100.0

# %% [markdown]
# # Task 3: Find Palindrome Words
# You are asked to write a function that finds the plaindrome words and flag them as "True", otherwise "False".
#
# Constraints:
# - Function must also accept lists, not only string values.
# - Keep in mind that words can be given in any style.
# - Function needs to return a boolean value(True or False).
# - You are allowed to use loops, filters, recursives or lists.

# %%
def is_palindrome(word):
    # FILL HERE
    word = [let.lower() for let in word]
    return word == word[::-1]

# %% [markdown]
# ## Test your function with test cases below:

# %%
# DO NOT CHANGE HERE
check_function(
    ["APPLE","MADAM","kAYaK","CAT","",[],"EY EDIP ADANADA PIDE YE","Python",["a","b","a"]],
    [False,True,True,False,True,True,True,False,True],
    is_palindrome
)
# Out:
# APPLE                     -> Right Answer: False      , User Answer: False
# MADAM                     -> Right Answer: True       , User Answer: True
# kAYaK                     -> Right Answer: True       , User Answer: True
# CAT                       -> Right Answer: False      , User Answer: False
#                           -> Right Answer: True       , User Answer: True
# []                        -> Right Answer: True       , User Answer: True
# EY EDIP ADANADA PIDE YE   -> Right Answer: True       , User Answer: True
# Python                    -> Right Answer: False      , User Answer: False
# ['a', 'b', 'a']           -> Right Answer: True       , User Answer: True
# --------------------------------------------------
# Point: %100.0

# %% [markdown]
# # Task 4: The Perpendicularity Test
# Complete two functions below:
# - dot_product(vector1, vector2): Calculates the scalar product.
# - is_orthogonal(vector1, vector2): Returns True if the vectors are orthogonal, False otherwise.
#
# Constraints:
# - All the inputs will be only lists.
# - Keep in mind that vectors may have different lengths.
# - If vectors have different lengths, return False.

# %%
def dot_product(vector1, vector2):
    # FILL HERE
    return sum([x*y for x,y in zip(vector1, vector2)])

def is_orthogonal(data):
    vector1, vector2 = data[0], data[1]
    # FILL HERE
    if len(vector1)!=len(vector2):
        return False
    if dot_product(vector1, vector2)==0:
        return True
    return False

# %% [markdown]
# ## Test your function with test cases below:

# %%
# DO NOT CHANGE HERE
check_function(
    [([1, 0], [0, 1]), ([1,2],[4,5,6]), ([1, 2, 3], [4, 5, 6]), ([3, -1], [1, 3]), ([1, 1], [1, 1]), ([3,4,5],[-9,2,3.8])],
    [True, False, False, True, False, True],
    is_orthogonal
)
# Out:
# ([1, 0], [0, 1])          -> Right Answer: True       , User Answer: True
# ([1, 2], [4, 5, 6])       -> Right Answer: False      , User Answer: False
# ([1, 2, 3], [4, 5, 6])    -> Right Answer: False      , User Answer: False
# ([3, -1], [1, 3])         -> Right Answer: True       , User Answer: True
# ([1, 1], [1, 1])          -> Right Answer: False      , User Answer: False
# ([3, 4, 5], [-9, 2, 3.8]) -> Right Answer: True       , User Answer: True
# --------------------------------------------------
# Point: %100.0

# %% [markdown]
# ## End of the Homework
